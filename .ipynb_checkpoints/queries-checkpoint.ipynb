# %% [markdown]
# **Question 1:** Revenue Leakage Analysis
# "Which product categories have the highest cancellation rates, and what's the revenue impact?"
# **Business Insight to Include:**
# "Category X accounts for 23% of cancellations but only 8% of total orders, indicating potential product-market fit issues."
#
# <hr>
#
# **Question 2:** Customer Segmentation (RFM Analysis)
# "Which customer segments generate 80% of revenue?"
#
# <hr>
#
# **Question 3:** Regional Performance with Growth Trends
# "Which regions show declining vs. growing sales trends?"
#
# <hr>
#
# **Question 4:** Delivery Performance Analysis
# "Which sellers consistently deliver late, and how does it affect reviews?"
#
# <hr>
#
#
# <hr>
#
# **Question 7:** 90-Day Rolling Revenue Trend
# "What's our revenue momentum over time?"

# %% [markdown]
# If time permits:
#
#
# **Question 5:** Product Performance Ranking
# "What are the top 10 products by revenue in each category?"
#
# <hr>
#
# **Question 6:** Payment Method Analysis
# "How do payment methods correlate with order value and customer loyalty?"

# %% [markdown]
# ## RFM:
# Q1. How can customers be segmented based on Recency, Frequency, and Monetary value?
#
# Q2. How are customers distributed across Recency, Frequency, and Monetary values?
#
# Q3. How can RFM scores be assigned to customers?
#
# Q4. What distinct customer segments exist based on RFM scores?
#
# Q5. Which customer segments contribute the most to revenue?
#
# Q5. Which customer segments contribute the most to revenue?
#
# Q7. Do certain RFM segments show higher cancellation behavior?
#
# Q8. What business actions can be derived from RFM segmentation?
#
#
# Hypothesis 1:
# A small percentage of customers contribute a disproportionately large share of revenue (Pareto principle).
#
#
# Hypothesis 2:
# Customers with high monetary value but low recency represent the biggest retention opportunity.
#
#
# Hypothesis 3:
# Low-frequency, low-monetary customers have higher cancellation tendencies.

# %%
import pandas as pd
import sqlite3
from sqlalchemy import create_engine
db_path = "data/ecommerce.db"
conn = sqlite3.connect(db_path)

# %%
test = pd.read_sql_query(open("sql/test.sql").read(), conn)

# %%
test
# Out:
#                            name
# 0                     customers
# 1                   geolocation
# 2                        orders
# 3                   order_items
# 4                order_payments
# 5                 order_reviews
# 6                      products
# 7                       sellers
# 8  product_category_translation
